# %%
import pandas as pd
import numpy as np

df = pd.read_csv("./GB_youtube_trending_data.csv")

# %%
df.sort_values(
    by="view_count",
    ascending = False
)[["title", "view_count","tags"]].head(100)
# Out:
#                                                     title  view_count  \
# 2953                   BTS (방탄소년단) 'Dynamite' Official MV   208581468
# 2699                   BTS (방탄소년단) 'Dynamite' Official MV   200692965
# 68781                      JETSKI WAX PRANK!! 🤣 - #Shorts   194625542
# 68533                      JETSKI WAX PRANK!! 🤣 - #Shorts   187175462
# 2454                   BTS (방탄소년단) 'Dynamite' Official MV   183414472
# ...                                                   ...         ...
# 571     Cardi B - WAP feat. Megan Thee Stallion [Offic...    88240316
# 59902                      HOW CRYPTOCURRENCY WORKS 💸👨🏻‍💻    88111813
# 120461  Watch the uncensored moment Will Smith smacks ...    87949852
# 102194  Crazy #alluarjun #painting  #shorts #viral #tr...    87563278
# 67744                 Turn into orbeez - Tutorial #Shorts    87280374
#
#                                                      tags
# 2953                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄
# 2699                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄
# 68781                                         Julius Dein
# 68533                                         Julius Dein
# 2454                      BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄
# ...                                                   ...
# 571     Cardi B|Cardi|Atlantic Records|rap|hip hop|tra...
# 59902   alan chikin chow|tiktok|superhero fanfics be l...
# 120461  Jada Pinkett Smith|Jada Pinkett Smith chris ro...
# 102194                                             [None]
# 67744                                              [None]
#
# [100 rows x 3 columns]

# %%
from collections import Counter
Counter(" ".join(df["tags"]).split()).most_common(2000)
# Out:
# [('[None]', 24142),
#  ('vs', 23744),
#  ('the', 23170),
#  ('and', 19689),
#  ('of', 19093),
#  ('to', 15646),
#  ('in', 15128),
#  ('a', 10945),
#  ('United', 10048),
#  ('new', 7763),
#  ('on', 6326),
#  ('season', 5966),
#  ('league', 5529),
#  ('with', 5425),
#  ('you', 5089),
#  ('my', 5074),
#  ('minecraft', 4822),
#  ('for', 4375),
#  ('game', 4332),
#  ('us', 4106),
#  ('The', 4012),
#  ('2', 3921),
#  ('v', 3898),
#  ('music', 3649),
#  ('highlights', 3604),
#  ('Utd', 3503),
#  ('is', 3417),
#  ('United|Man', 3406),
#  ('me', 3370),
#  ('but', 3354),
#  ('live', 3326),
#  ('days', 3251),
#  ('Sports', 3248),
#  ('100', 3218),
#  ('it', 3080),
#  ('22', 3006),
#  ('5', 2976),
#  ('sports', 2934),
#  ('life', 2895),
#  ('minecraft|minecraft', 2879),
#  ('3', 2822),
#  ('best', 2735),
#  ('Manchester', 2721),
#  ('12', 2649),
#  ('i', 2642),
#  ('man', 2639),
#  ('official', 2614),
#  ('4', 2506),
#  ('sky', 2449),
#  ('&', 2440),
#  ('2021', 2344),
#  ('at', 2336),
#  ('I', 2309),
#  ('world', 2304),
#  ('home', 2219),
#  ('full', 2193),
#  ('de', 2176),
#  ('paul', 2175),
#  ('pro', 2150),
#  ('series', 2125),
#  ('Minecraft', 2086),
#  ('chapter', 2052),
#  ('real', 2043),
#  ('night', 1997),
#  ('no', 1997),
#  ('x', 1993),
#  ('battle', 1991),
#  ('Transfer', 1985),
#  ('funny', 1974),
#  ('video', 1946),
#  ('Legends', 1926),
#  ('-', 1841),
#  ('1', 1835),
#  ('perfect', 1830),
#  ('way', 1797),
#  ('out', 1777),
#  ('city', 1767),
#  ('legends', 1761),
#  ('2020', 1743),
#  ('island', 1709),
#  ('by', 1700),
#  ('tok', 1660),
#  ('your', 1652),
#  ('tour', 1614),
#  ('impact', 1594),
#  ('love', 1567),
#  ('cup', 1548),
#  ('Utd|Manchester', 1547),
#  ('Stand|United', 1542),
#  ('first', 1539),
#  ('football', 1538),
#  ('be', 1534),
#  ('fan', 1533),
#  ('13', 1530),
#  ('got', 1523),
#  ('News|MUFC|Man', 1512),
#  ('news', 1504),
#  ('Stand|Manchester', 1501),
#  ('hardcore', 1496),
#  ('trailer', 1495),
#  ('among', 1490),
#  ('theory', 1486),
#  ('episode', 1486),
#  ('all', 1486),
#  ('star', 1475),
#  ('sports|premier', 1453),
#  ('21', 1450),
#  ('TV|The', 1450),
#  ('Man', 1448),
#  ('one', 1447),
#  ('League', 1442),
#  ('League|football|Sky', 1442),
#  ('live|Sky|Sports|stream|sky', 1436),
#  ('league|Football', 1435),
#  ('football|premier', 1433),
#  ('Clans', 1432),
#  ('fortnite', 1421),
#  ('News|United|Manchester', 1416),
#  ('day', 1410),
#  ('war', 1384),
#  ('press', 1382),
#  ('play', 1371),
#  ('car', 1355),
#  ('6', 1338),
#  ('Season', 1333),
#  ('fortnite|fortnite', 1327),
#  ('up', 1324),
#  ('not', 1314),
#  ('united', 1303),
#  ('Gunnar', 1282),
#  ('house', 1274),
#  ('Music', 1269),
#  ('mix', 1256),
#  ('security', 1250),
#  ('max', 1242),
#  ('7', 1230),
#  ('this', 1219),
#  ('14', 1219),
#  ('playtime', 1214),
#  ('10', 1210),
#  ('or', 1191),
#  ('time', 1178),
#  ('make', 1176),
#  ('from', 1168),
#  ('family', 1162),
#  ('New', 1157),
#  ('get', 1153),
#  ('2022', 1152),
#  ('tv', 1143),
#  ('we', 1143),
#  ('sheeran', 1140),
#  ('do', 1138),
#  ('bottle', 1115),
#  ('Show', 1111),
#  ('things', 1111),
#  ('ring', 1100),
#  ('shop', 1094),
#  ('games', 1091),
#  ('song', 1088),
#  ('8', 1087),
#  ('A', 1083),
#  ('highlights|epl', 1074),
#  ('In', 1069),
#  ('open', 1063),
#  ('Norton', 1055),
#  ('van', 1052),
#  ('drag', 1042),
#  ('challenge|minecraft', 1041),
#  ('tik', 1037),
#  ('wars', 1024),
#  ('vs.', 1021),
#  ('squad', 1020),
#  ('You', 1019),
#  ('To', 1018),
#  ('how', 1012),
#  ('survived', 1010),
#  ('food', 1009),
#  ('like', 992),
#  ('iphone', 979),
#  ('smith', 972),
#  ('youtube|youtube', 969),
#  ('challenge', 964),
#  ('fifa', 956),
#  ('With', 944),
#  ('makeup', 943),
#  ('an', 941),
#  ('dog', 929),
#  ('baby', 924),
#  ('that', 922),
#  ('red', 920),
#  ('World', 919),
#  ('ball', 907),
#  ('survival|minecraft', 905),
#  ('breach', 905),
#  ('Me', 901),
#  ('cat', 898),
#  ('My', 877),
#  ('Official', 874),
#  ('what', 874),
#  ('review', 873),
#  ('One|Formula', 871),
#  ('grand', 868),
#  ('every', 864),
#  ('Football', 863),
#  ('interview', 860),
#  ('Graham', 856),
#  ('News|Manchester', 851),
#  ('voice', 851),
#  ('about', 849),
#  ('boxing', 845),
#  ('24', 839),
#  ('Solskjaer|Solskjaer', 835),
#  ('are', 829),
#  ('days|100', 828),
#  ('goal', 827),
#  ('final', 827),
#  ('hardcore|minecraft', 816),
#  ('News|Transfer|Solskjaer|Ole', 814),
#  ('tom', 808),
#  ('story', 803),
#  ('tries', 801),
#  ('TV', 798),
#  ('bad', 798),
#  ('kay', 797),
#  ('utd', 795),
#  ('show', 793),
#  ('Cup', 786),
#  ('manhunt|minecraft', 786),
#  ('Minecraft|Minecraft', 786),
#  ('F1|Formula', 785),
#  ('Got', 770),
#  ('champions', 758),
#  ('yoga', 757),
#  ('item', 755),
#  ('as', 753),
#  ('cricket', 743),
#  ('lil', 742),
#  ("don't", 742),
#  ('durk', 742),
#  ('sport', 741),
#  ('tiktok', 738),
#  ('uk', 733),
#  ('can', 725),
#  ('manchester', 716),
#  ('test', 716),
#  ('england', 715),
#  ('raw', 711),
#  ('Ramsay', 706),
#  ('fa', 701),
#  ('boy', 699),
#  ('big', 695),
#  ('morning', 694),
#  ('Talent', 691),
#  ('Hag', 691),
#  ('match', 690),
#  ('flip|dude', 687),
#  ('wrestling', 680),
#  ('City', 680),
#  ('but|minecraft', 680),
#  ('Paul', 679),
#  ('logan', 677),
#  ('1|Sports|Sport|Action|GP|Grand', 677),
#  ('Prix|Auto', 677),
#  ('Racing|Motor', 677),
#  ('mod|minecraft', 674),
#  ('water', 672),
#  ('nights', 672),
#  ('training', 670),
#  ('Latest', 668),
#  ('fury', 667),
#  ('top', 663),
#  ('Sports|Sky', 662),
#  ('Grand', 660),
#  ('good', 660),
#  ('made', 659),
#  ('survival', 659),
#  ('fight', 658),
#  ('prime', 653),
#  ('hot', 652),
#  ('West', 649),
#  ('swift', 646),
#  ('Late', 645),
#  ('calorie', 644),
#  ('la', 643),
#  ('speedrunner', 643),
#  ('google', 642),
#  ('thee', 642),
#  ('ready', 641),
#  ('ones', 636),
#  ('Game', 635),
#  ('golf', 629),
#  ('f1', 627),
#  ('Of', 626),
#  ('johnson', 625),
#  ('pokemon', 621),
#  ('sidemen|moresidemen|miniminter|ksi|zerkaa|behzinga|tbjzl|vikkstar|wroetoshaw',
#   620),
#  ('National', 619),
#  ('hour', 619),
#  ('eilish', 617),
#  ('come', 611),
#  ('gala', 611),
#  ('post', 610),
#  ('minecraft|100', 610),
#  ('body', 609),
#  ('little', 608),
#  ('punk', 606),
#  ('does', 606),
#  ('black', 604),
#  ('west', 604),
#  ('harlow', 599),
#  ('clans', 596),
#  ('update|fortnite', 594),
#  ('eating', 593),
#  ('euro', 591),
#  ('डब्लू', 585),
#  ('manhunt', 585),
#  ('Sport', 584),
#  ('Jadon', 584),
#  ('team', 580),
#  ('hours', 579),
#  ('player', 578),
#  ('america', 578),
#  ('duty', 576),
#  ('Boxing', 575),
#  ('school', 573),
#  ('go', 571),
#  ('release', 564),
#  ('virtual', 564),
#  ('part', 563),
#  ('g', 561),
#  ('pack', 560),
#  ('movie', 558),
#  ('kardashian', 558),
#  ('last', 557),
#  ('hide', 557),
#  ('money', 555),
#  ('mcgregor', 554),
#  ('2021|new', 550),
#  ('del', 549),
#  ('Video', 547),
#  ('online', 547),
#  ('watch', 546),
#  ('met', 544),
#  ('call', 542),
#  ('beat', 542),
#  ('custom', 542),
#  ('morty', 541),
#  ('simulator', 540),
#  ('update', 540),
#  ('us|among', 540),
#  ('gameplay', 539),
#  ('dream', 537),
#  ('into', 536),
#  ('mayweather', 536),
#  ('Best', 534),
#  ('brown', 534),
#  ('super', 532),
#  ('Sancho|Sancho|Manchester', 530),
#  ('grande', 529),
#  ('reacts', 528),
#  ('kids', 528),
#  ('But', 528),
#  ('songs', 527),
#  ('race', 526),
#  ('white', 524),
#  ('smp', 524),
#  ('map', 521),
#  ('only', 519),
#  ('barker', 518),
#  ('model', 518),
#  ('park', 517),
#  ('Sky', 517),
#  ('No', 517),
#  ('Garros', 517),
#  ('championship', 516),
#  ('Apex', 511),
#  ('who', 509),
#  ('rap', 509),
#  ('know', 509),
#  ('build', 508),
#  ('horizon', 507),
#  ('Night', 507),
#  ('pregnancy', 506),
#  ('rose', 506),
#  ('light', 506),
#  ('farm', 506),
#  ('s', 504),
#  ('ultra', 502),
#  ('taylor', 502),
#  ('Fury', 502),
#  ('bt', 500),
#  ('james', 500),
#  ('news|Solskjaer', 499),
#  ('easter', 499),
#  ('(TV', 498),
#  ('youtube', 497),
#  ('price', 497),
#  ('free', 496),
#  ('cyrus', 495),
#  ('All', 493),
#  ('joe', 492),
#  ('comedy', 491),
#  ('Press', 490),
#  ('rock', 489),
#  ('sidemen|sidemen', 488),
#  ('holiday', 488),
#  ('Sims', 487),
#  ('hip', 486),
#  ('On', 486),
#  ('9', 485),
#  ('over', 485),
#  ('too', 484),
#  ('office', 483),
#  ('door', 481),
#  ('saffron', 479),
#  ('daylight', 479),
#  ('holland', 478),
#  ('highlights|england', 477),
#  ('fc', 475),
#  ('G', 474),
#  ('will', 471),
#  ('xbox', 469),
#  ('secret', 468),
#  ('NBA', 467),
#  ('THE', 467),
#  ('ham', 467),
#  ('kitchen', 466),
#  ('premier', 464),
#  ('News|Man', 464),
#  ('right', 464),
#  ('days|minecraft', 464),
#  ('Royale', 463),
#  ('talent', 463),
#  ('F1', 463),
#  ('Lil', 461),
#  ('speed', 456),
#  ('stop', 456),
#  ('clash', 454),
#  ('20', 453),
#  ('liana', 453),
#  ('beauty', 452),
#  ('minute', 451),
#  ('Love', 448),
#  ('rocket', 447),
#  ('shorts', 447),
#  ('apex', 447),
#  ('back', 446),
#  ('off', 444),
#  ('so', 441),
#  ('have', 441),
#  ('buy', 439),
#  ('sport|bt', 438),
#  ('chelsea', 438),
#  ('2077', 437),
#  ('Bull', 436),
#  ('face', 435),
#  ('Nas', 435),
#  ('boys', 434),
#  ('jake', 434),
#  ('christmas', 434),
#  ('mode', 433),
#  ('nas', 432),
#  ('Formula', 432),
#  ('reaction', 431),
#  ('weeknd', 430),
#  ('im', 430),
#  ('fire', 429),
#  ('2020|Manchester', 429),
#  ('king', 429),
#  ('copa', 429),
#  ('Hag|Ten', 428),
#  ('nba', 427),
#  ('expensive', 426),
#  ('fighters', 425),
#  ('speedrunner|minecraft', 424),
#  ('royale', 423),
#  ('PARIS', 423),
#  ('Black', 422),
#  ('indies', 422),
#  ('n', 421),
#  ('Real', 421),
#  ('shopping', 421),
#  ('jenner', 420),
#  ('Sheeran', 419),
#  ('British', 417),
#  ('challenge|challenge|minecraft', 417),
#  ('arsenal', 416),
#  ('X', 416),
#  ('its', 415),
#  ('harry', 412),
#  ('type', 411),
#  ('funniest', 408),
#  ('apple', 407),
#  ('tv|arsenal', 406),
#  ('friends', 404),
#  ('united|man', 403),
#  ('food|beard', 402),
#  ('911', 400),
#  ('street', 400),
#  ('Shiels', 399),
#  ('squid', 399),
#  ('sunday|#sidemensunday', 398),
#  ('bunny', 398),
#  ('royale|fortnite', 398),
#  ('doctor', 397),
#  ('2042', 397),
#  ('iPhone', 395),
#  ('wild', 395),
#  ('girls', 394),
#  ('15', 394),
#  ('event|fortnite', 394),
#  ('fashion', 394),
#  ('hunter|minecraft', 393),
#  ('weigh', 393),
#  ('Liverpool', 393),
#  ('take', 392),
#  ('minecraft|mine', 392),
#  ('sonic', 391),
#  ('other', 391),
#  ('Shows', 390),
#  ('|', 390),
#  ('thug', 388),
#  ('david', 387),
#  ('wilder', 387),
#  ('dec', 387),
#  ('young', 385),
#  ('beta', 385),
#  ('lets', 385),
#  ('speedrun|minecraft', 385),
#  ('afc|aftv|arsenal|arsenal', 384),
#  ('tv|fan', 384),
#  ('cams|arsenal', 384),
#  ('league|robbie', 384),
#  ('arteta|aftv', 384),
#  ('Gunz', 384),
#  ('fighting', 384),
#  ('trailers', 383),
#  ('trailer|Battlefield', 383),
#  ('gym', 382),
#  ('total', 382),
#  ('base', 381),
#  ('Race', 381),
#  ('floyd', 381),
#  ('First', 379),
#  ('review|car', 379),
#  ('bieber', 379),
#  ('daily', 378),
#  ('road', 377),
#  ('jordan', 377),
#  ('reveal', 376),
#  ('streaming|mu', 375),
#  ('Pro', 375),
#  ('Battle', 373),
#  ('charles', 373),
#  ('galaxy', 373),
#  ('leave', 373),
#  ('fans', 373),
#  ('Days', 372),
#  ('results|The', 372),
#  ('Lottery', 372),
#  ('game|genshin', 372),
#  ('videos|funny', 371),
#  ('gta', 371),
#  ('better', 371),
#  ("d'amelio", 371),
#  ('moments', 371),
#  ('nelson', 369),
#  ('Pepe|All', 369),
#  ('Blazing|transfer', 369),
#  ('art', 368),
#  ('FC', 367),
#  ('chris', 367),
#  ('sneaker', 366),
#  ('Stars', 366),
#  ('Episode', 364),
#  ('pub', 364),
#  ('tips', 363),
#  ('prince', 363),
#  ('year', 363),
#  ('Dine', 363),
#  ('girl', 362),
#  ('Solskjaer', 361),
#  ('dont', 360),
#  ('training|england', 360),
#  ('book', 359),
#  ('much', 359),
#  ('News', 359),
#  ('quiz|online', 358),
#  ('john', 355),
#  ('Series', 355),
#  ('iOS', 355),
#  ('theory|film', 354),
#  ('Super', 354),
#  ('stallion', 354),
#  ('For', 354),
#  ('conference|Ole', 354),
#  ('Indies', 354),
#  ('cook', 353),
#  ('Every', 353),
#  ('dude', 353),
#  ('stereotypes|dude', 353),
#  ('ariana', 353),
#  ('Is', 352),
#  ('stand', 351),
#  ('1.19', 351),
#  ('jack', 350),
#  ('Park', 350),
#  ('broke', 349),
#  ('try', 348),
#  ('gomez', 348),
#  ('Your', 348),
#  ('savage', 348),
#  ('perfect|dude', 347),
#  ('flip|bottle', 347),
#  ('flip|water', 347),
#  ('shots|trick', 347),
#  ('shot|family|ping', 347),
#  ('pong|bowling|clean|family', 347),
#  ('game|mobile', 346),
#  ('cant', 346),
#  ('career', 345),
#  ('Live', 345),
#  ('block', 345),
#  ('event', 345),
#  ('if', 344),
#  ('electric', 344),
#  ('mystery', 344),
#  ('liverpool', 344),
#  ('al', 344),
#  ('most', 344),
#  ('Never', 343),
#  ('room', 343),
#  ("let's", 343),
#  ('boba', 343),
#  ('friendly|bubble', 342),
#  ('shoe', 342),
#  ('Ham', 342),
#  ('play|minecraft', 342),
#  ('video|pop', 341),
#  ('b', 341),
#  ('basketball|dp|dude', 340),
#  ('class', 340),
#  ('Aubameyang|Aubameyang|Nicolas', 339),
#  ('air', 339),
#  ('Lipa', 338),
#  ('Roland', 338),
#  ('De', 337),
#  ('rodrigo', 336),
#  ('aston', 335),
#  ('record|edition|nerf|trick', 334),
#  ('live|Man', 334),
#  ('wanna', 333),
#  ('ios', 333),
#  ('easy', 332),
#  ('box', 331),
#  ('Premiership', 330),
#  ('Soccer', 330),
#  ('alvarez', 329),
#  ('da', 328),
#  ('hit', 328),
#  ('max|iphone', 328),
#  ('zealand', 328),
#  ('ई|मैच|सुपरस्टार|व्यावसायिक', 327),
#  ('club', 327),
#  ('inside', 327),
#  ('smash', 327),
#  ('lyle|troopz|dt|aftvmedia|david', 326),
#  ('her', 325),
#  ('lanez', 325),
#  ('down', 324),
#  ('Vs', 324),
#  ('Ronaldo|Ronaldo', 324),
#  ("didn't", 324),
#  ('news|Pierre-Emerick', 324),
#  ('faze', 323),
#  ('ice', 323),
#  ('kick', 322),
#  ('11', 322),
#  ('british', 322),
#  ('mcrae', 322),
#  ('hacks|crafts|slime|do', 322),
#  ('yourself|diy|lifehacks|dily', 322),
#  ('projects|useful', 322),
#  ('things|how', 322),
#  ('to|experiment|experiments|diy', 322),
#  ('activities|handcraft|prank|funny|challenge|pranks|secret|diy', 322),
#  ('slime|laugh|new|skills|tricks|tips|fun', 322),
#  ('Wars', 321),
#  ('was', 321),
#  ('more', 321),
#  ('Way', 320),
#  ('wrap|soccer|football|spinner|spinners|fidget', 320),
#  ('miles', 320),
#  ('city|man', 319),
#  ('ultimate', 319),
#  ('wwe|world', 319),
#  ('entertainment|wrestling|wrestler|wrestle|superstars|कुश्ती|पहलवान|डब्लू',
#   319),
#  ('2-1', 319),
#  ('worst', 319),
#  ('malone', 319),
#  ('It', 318),
#  ('power', 318),
#  ('2-0', 318),
#  ('icon', 318),
#  ('vlog', 317),
#  ('Music|GRM|GRM', 317),
#  ('Daily|Video|music', 317),
#  ('there', 317),
#  ('infinite', 317),
#  ('gender', 316),
#  ('कुश्ती|مصارعه|wwe', 315),
#  ('BBC|BBC', 315),
#  ('bought', 314),
#  ('ever', 314),
#  ('Broke', 313),
#  ('am', 313),
#  ('let', 313),
#  ('meets', 313),
#  ('behind', 310),
#  ('Open', 310),
#  ('long', 310),
#  ('album', 309),
#  ('break', 309),
#  ('Town', 308),
#  ('F2', 308),
#  ('bobby', 307),
#  ('coming', 306),
#  ('lyric', 306),
#  ('our', 305),
#  ('news|MU', 305),
#  ('say', 305),
#  ('rogan', 305),
#  ('FIFA', 304),
#  ('taste', 304),
#  ('skin', 304),
#  ('tyson', 304),
#  ('Dream', 304),
#  ('Joshua', 303),
#  ('gaming', 303),
#  ('animation', 302),
#  ('Joe', 302),
#  ('awards', 302),
#  ('craft|minecraft', 301),
#  ('drive', 299),
#  ('mario', 299),
#  ('card', 298),
#  ('midnight', 297),
#  ('elizabeth', 297),
#  ('feat.', 296),
#  ('cold', 296),
#  ('VS', 295),
#  ('rocky', 295),
#  ('scott|tomscott', 295),
#  ('liga|laliga|laliga', 295),
#  ('Soccer|Football|Calfreezy|Rebel|Rebel', 295),
#  ('FC|London|England|How', 295),
#  ('to|Footy|Tekkers|YouTuber|Challenge|Soccer', 295),
#  ('Skills|Football', 295),
#  ('Skill|Trick', 295),
#  ('Shots|Soccer', 295),
#  ('Fails|Football', 295),
#  ('Fails|Tricks|Freestyle', 295),
#  ('Football|funny|comedy|friends|vlog|vlogging|freezy', 295),
#  ('minecraft|funny|minecraft', 295),
#  ('From', 294),
#  ('should', 294),
#  ('boi', 294),
#  ('lore', 293),
#  ('people', 293),
#  ('yes', 293),
#  ('end', 293),
#  ('daily|gabriel|willian|thomas', 293),
#  ('york', 292),
#  ('jianhao', 292),
#  ('wins', 292),
#  ('Rocket', 291),
#  ('dazn|boxing|highlights|full', 291),
#  ('ufc', 290),
#  ('batman', 290),
#  ('Red', 290),
#  ('Full', 290),
#  ('find', 290),
#  ('d', 290),
#  ('dantdm|dan', 290),
#  ('goals', 289),
#  ('1.17', 289),
#  ('Top', 288),
#  ('TO', 288),
#  ('teaser', 288),
#  ('lost', 288),
#  ('drew', 287),
#  ('Car', 287),
#  ('boxing|sky', 287),
#  ('work', 287),
#  ('boss', 287),
#  ('jr', 287),
#  ('bowl', 287),
#  ('india', 287),
#  ('interview|Ten', 287),
#  ('paul|jake', 286),
#  ('highlights|arsenal', 286),
#  ('Cycling', 286),
#  ('jay', 286),
#  ('Tiller', 286),
#  ('pixel', 286),
#  ('s21', 286),
#  ('Day', 285),
#  ('Show|The', 285),
#  ('carwow|mat', 284),
#  ('mobile', 284),
#  ('wilbur', 284),
#  ('plus', 283),
#  ('city|manchester', 282),
#  ('pro|iphone', 282),
#  ('seek', 282),
#  ('preview|Cristiano', 282),
#  ('blue', 281),
#  ('beast', 281),
#  ('thompson', 281),
#  ('danny', 280),
#  ('messi', 280),
#  ('Chelsea', 279),
#  ('england|england', 279),
#  ('guess', 279),
#  ('amazon', 279),
#  ('video|minecraft', 279),
#  ('trailer|apex', 279),
#  ('doja', 278),
#  ('workout', 278),
#  ('trailer|new', 278),
#  ('Fortnite', 278),
#  ('true', 277),
#  ('Like', 277),
#  ('Up', 277),
#  ('kid', 277),
#  ('hall', 277),
#  ('stranger', 277),
#  ('What', 276),
#  ('bull', 276),
#  ('heart', 275),
#  ('update|new', 275),
#  ('old', 275),
#  ('sims', 275),
#  ('craft|dream|dream', 275),
#  ('update|minecraft', 275),
#  ('talk', 274),
#  ('Be', 274),
#  ('hunters|Speedrunner', 274),
#  ('hair', 273),
#  ('short', 273),
#  ('tracey', 273),
#  ('birthday', 272),
#  ('league|premier', 272),
#  ('hill', 272),
#  ('myths', 272),
#  ('pilots', 271),
#  ('six', 270),
#  ('returns', 270),
#  ('look', 270),
#  ('9|hermitcraft', 270),
#  ('stream|mu', 269),
#  ('need', 269),
#  ('after', 269),
#  ('reviews', 269),
#  ('ending', 269),
#  ('hermitcraft|hermitcraft', 269),
#  ('shooter|Apex', 268),
#  ('green', 267),
#  ('News|Transfer', 267),
#  ('michael', 267),
#  ('high', 266),
#  ('stream|live', 266),
#  ('ksi', 266),
#  ("freddy's", 266),
#  ('dragon', 266),
#  ('funny|minecraft', 266),
#  ('latest', 265),
#  ('2020|euro', 265),
#  ('t', 264),
#  ('today', 264),
#  ('nail', 264),
#  ('simon|sidemen|miniminter|mm7games|random|vlog', 264),
#  ('Royale|Fortnite', 264),
#  ('2021|2021', 264),
#  ('royal', 263),
#  ('Gallagher', 263),
#  ('dress', 262),
#  ('macbook', 262),
#  ('fett', 262),
#  ('next', 261),
#  ('lie', 261),
#  ('8|hermitcraft', 261),
#  ('well', 260),
#  ('dark', 260),
#  ('chamberlain', 260),
#  ('villa', 260),
#  ('Sincerely', 260),
#  ('YG', 259),
#  ('cup|fa', 259),
#  ('plays', 259),
#  ('dad', 259),
#  ('0', 259),
#  ('partey|aftv', 259),
#  ('FC|LFC|Liverpool|Anfield|Melwood|Liverpool', 258),
#  ('Club|premier', 258),
#  ('entertainment|wrestle|wrestler|wrestling|wwe|wwe', 258),
#  ('whats', 257),
#  ('machine', 257),
#  ('Us', 257),
#  ('bbc|bbc', 257),
#  ('ross', 257),
#  ('shooting', 257),
#  ('Ten', 257),
#  ('hop', 256),
#  ('12|iphone', 256),
#  ('stars', 256),
#  ('2021|مصارعه|कुश्ती|डब्लू', 256),
#  ('F1|Sky', 255),
#  ('transfer', 255),
#  ('pop', 254),
#  ('30', 254),
#  ('south', 254),
#  ('titan', 254),
#  ('Highlights|Scottish', 253),
#  ('charlie', 253),
#  ('chicken', 253),
#  ('ई|पहलवान|मैच|व्यावसायिक', 253),
#  ('makeup|makeup', 252),
#  ('own', 252),
#  ('when', 252),
#  ('Star', 252),
#  ('cinematic', 252),
#  ('1-0', 252),
#  ('party', 252),
#  ('stream|boxing|sky', 251),
#  ('dixie', 251),
#  ('jeremy', 251),
#  ('darby', 251),
#  ('UK', 251),
#  ('cursing|no', 251),
#  ('highlights|scottish', 250),
#  ('키즈', 250),
#  ('Games|Fortnite', 250),
#  ('golden', 250),
#  ('tiktoks', 250),
#  ('Villareal|Manchester', 250),
#  ('makeup|tik', 249),
#  ('nightmares', 249),
#  ('ronaldo', 249),
#  ('aew', 249),
#  ('Jordan', 248),
#  ('football|football', 248),
#  ('gear|the', 248),
#  ('ben', 248),
#  ('funny|funniest', 248),
#  ('depp', 248),
#  ('Spurs|Tottenham', 247),
#  ('potter', 247),
#  ('rescue', 247),
#  ('mom', 247),
#  ('Things', 247),
#  ('Hollywood', 247),
#  ('touch', 247),
#  ('SMP|School', 247),
#  ('Arsenal|Arsenal', 246),
#  ('damelio|dixie', 246),
#  ('workout|fitness', 246),
#  ('highlights|euro', 246),
#  ('poppy', 246),
#  ('driver', 245),
#  ('perry', 244),
#  ('god', 244),
#  ('Home', 244),
#  ('friend', 244),
#  ('50', 244),
#  ('vogue', 244),
#  ('wan', 244),
#  ('s22', 244),
#  ('Premiership|Scottish', 243),
#  ('League|Champions', 243),
#  ('crash', 243),
#  ('jones', 243),
#  ('hotel', 243),
#  ('gol|migliori', 243),
#  ('orton', 242),
#  ('op', 242),
#  ('impact|genshin', 242),
#  ('theory|game', 241),
#  ('clans|COC|Clash', 241),
#  ('Gameplay|Clash', 241),
#  ('Strategy|Clash', 241),
#  ('challenges|clan', 241),
#  ('justin', 241),
#  ('tommyinnit|minecraft|mine', 241),
#  ('clarkson', 241),
#  ('trailer|fifa', 240),
#  ('direct', 240),
#  ('dance', 240),
#  ('Derulo', 240),
#  ('lock', 240),
#  ...]

# %%
pd.Series(' '.join(df['tags']).lower().split()).value_counts()[:100]
# Out:
# the         27649
# vs          24363
# [none]      24142
# and         19982
# of          19827
#             ...
# fortnite     1699
# trailer      1698
# hardcore     1693
# among        1684
# car          1681
# Length: 100, dtype: int64

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text2 = " ".join(df['tags'])

word_cloud2 = WordCloud(width = 4500, height = 3000, random_state = 42, collocations = False, background_color = 'black', colormap = 'Pastel1').generate(text2)

# %%
plt.imshow(word_cloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

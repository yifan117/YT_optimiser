# %%
import pandas as pd
import numpy as np

df = pd.read_csv("./US_youtube_trending_data.csv")

# %%
df

# %%
df.sort_values(
    by="view_count",
    ascending = False
)[["title", "view_count","tags"]].head(100)
# Out:
#                                                    title  view_count  \
# 56374                   BTS (방탄소년단) 'Butter' Official MV   264407389
# 3358                  BTS (방탄소년단) 'Dynamite' Official MV   232649205
# 3137                  BTS (방탄소년단) 'Dynamite' Official MV   219110491
# 2894                  BTS (방탄소년단) 'Dynamite' Official MV   208581468
# 73564                Turn into orbeez - Tutorial #Shorts   206202284
# ...                                                  ...         ...
# 43374                         ROSÉ - 'On The Ground' M/V   103691157
# 89984                        Dice Stacks from $1 to $100   103564168
# 54740                 INSANE strawberry trick! 😨 #shorts   102584495
# 127339  PSY - 'That That (prod. & feat. SUGA of BTS)' MV   101189049
# 66306               MvRyhan Funny videos #tiktok #Shorts   100899313
#
#                                                      tags
# 56374                     BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄
# ...

# %%
from collections import Counter
Counter(" ".join(df["tags"]).split()).most_common(5000)
# Out:
# [('the', 26427),
#  ('and', 23389),
#  ('[None]', 23329),
#  ('of', 19830),
#  ('vs', 17517),
#  ('to', 16591),
#  ('in', 15956),
#  ('a', 12724),
#  ('new', 8499),
#  ('on', 8012),
#  ('us', 7404),
#  ('season', 6178),
#  ('you', 6105),
#  ('minecraft', 5681),
#  ('with', 5579),
#  ('music', 5390),
#  ('my', 5169),
#  ('game', 5037),
#  ('2', 4642),
#  ('is', 4604),
#  ('night', 4429),
#  ('The', 4344),
#  ('but', 4267),
#  ('for', 4169),
#  ('me', 4075),
#  ('&', 3984),
#  ('de', 3866),
#  ('days', 3611),
#  ('it', 3610),
#  ('100', 3610),
#  ('video', 3453),
#  ('minecraft|minecraft', 3322),
#  ('official', 3248),
#  ('5', 3240),
#  ('life', 3058),
#  ('at', 2930),
#  ('no', 2769),
#  ('3', 2704),
#  ('best', 2625),
#  ('Legends', 2599),
#  ('i', 2555),
#  ('I', 2519),
#  ('chapter', 2517),
#  ('4', 2516),
#  ('12', 2508),
#  ('among', 2493),
#  ('home', 2458),
#  ('full', 2376),
#  ('paul', 2348),
#  ('by', 2345),
#  ('be', 2336),
#  ('world', 2317),
#  ('legends', 2295),
# ...

# %%
# pd.Series(' '.join(df['tags']).lower().split()).value_counts()[:500]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
text2 = " ".join(df['tags'])

word_cloud2 = WordCloud(width = 4500, height = 3000, random_state = 42, collocations = False, background_color = 'black', colormap = 'Pastel1').generate(text2)

# %%
plt.imshow(word_cloud2, interpolation='bilinear')
plt.axis("off")
plt.show()
